# %%
import sqlite3

with sqlite3.connect('ipeds.db') as conn:
    print("Connection successful!")
    cur = conn.cursor()
    cur.execute("select name from sqlite_master where type='table'")
    tables = cur.fetchall()
    for item in tables:
        print(item)

    cur.execute("""select count(*)
                from raw_ipeds_ay_tuition_2021
                """)
    data = cur.fetchall()
    print(data)
# Out:
# Connection successful!
# ('raw_ipeds_directory_2021',)
# ('raw_ipeds_ay_tuition_2021',)
# [(16858,)]
