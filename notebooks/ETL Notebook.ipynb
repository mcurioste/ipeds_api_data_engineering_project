# %%
import sqlite3
import pandas as pd

# with sqlite3.connect('ipeds.db') as conn:
#     print("Connection successful!")
#     cur = conn.cursor()
#     # cur.execute("""
#     #             select name 
#     #             from sqlite_master 
#     #             where type='table'
#     #             """)
#     # tables = cur.fetchall()
#     # for item in tables:
#     #     print(item)

#     cur.execute("""
#                 select *
#                 from ipeds_raw_tuition
#                 """)
#     data = cur.fetchall()
#     tuition_raw_df = pd.DataFrame(data)

# %% [markdown]
# ### KPIs
# - Average Tuition (core metric)
# - Average Total Cost of Attendance (Most Important)
# - Most Expensive vs Most Affordable Institution
#
#
# This dashboard analyzes tuition and cost of attendance across U.S. higher education institutions using IPEDS data to identify affordability trends, institutional cost differences, and regional variation.

# %%
sql_tuition = """
              select *
              from ipeds_raw_tuition
              """

sql_directory = """
              select *
              from ipeds_raw_tuition
              """

with sqlite3.connect("../ipeds.db") as con:
    df_raw_tuition = pd.read_sql(sql_tuition,con)
    df_raw_directory = pd.read_sql(sql_directory,con)

# %%
df_raw_tuition
# Out:
#       unitid  year  fips  level_of_study  tuition_type  tuition_fees_ft  \
# 0     100654  2021     1               1             2          10024.0
# 1     100654  2021     1               1             3          10024.0
# 2     100654  2021     1               1             4          18634.0
# 3     100654  2021     1               2             2          11542.0
# 4     100654  2021     1               2             3          11542.0
# ...      ...   ...   ...             ...           ...              ...
# 9995  209490  2021    41               1             3          21998.0
# 9996  209490  2021    41               1             4          34274.0
# 9997  209490  2021    41               2             2          28460.0
# 9998  209490  2021    41               2             3          28460.0
# 9999  209490  2021    41               2             4          28460.0
#
#       tuition_ft  fees_ft  credit_hour_charge_pt  tuition_published  \
# 0         8610.0   1414.0                  287.0             8610.0
# 1         8610.0   1414.0                  287.0             8610.0
# 2        17220.0   1414.0                  574.0            17220.0
# 3        10128.0   1414.0                  422.0                NaN
# 4        10128.0   1414.0                  422.0                NaN
# ...          ...      ...                    ...                ...
# 9995     14760.0   7238.0                  410.0                NaN
# 9996     27036.0   7238.0                  751.0                NaN
# 9997     21222.0   7238.0                  760.0                NaN
# 9998     21222.0   7238.0                  760.0                NaN
# 9999     21222.0   7238.0                  760.0                NaN
#
#       fees_published  tuition_fees_published  tuition_pub_pct_increase  \
# 0             1414.0                 10024.0                       NaN
# 1             1414.0                 10024.0                       NaN
# 2             1414.0                 18634.0                       NaN
# 3                NaN                     NaN                       NaN
# 4                NaN                     NaN                       NaN
# ...              ...                     ...                       ...
# 9995             NaN                     NaN                       NaN
# 9996             NaN                     NaN                       NaN
# 9997             NaN                     NaN                       NaN
# 9998             NaN                     NaN                       NaN
# 9999             NaN                     NaN                       NaN
#
#       fees_pub_pct_increase      ingested_at_utc
# 0                       NaN  2026-02-11T08:35:04
# 1                       NaN  2026-02-11T08:35:04
# 2                       NaN  2026-02-11T08:35:04
# 3                       NaN  2026-02-11T08:35:04
# 4                       NaN  2026-02-11T08:35:04
# ...                     ...                  ...
# 9995                    NaN  2026-02-11T08:35:04
# 9996                    NaN  2026-02-11T08:35:04
# 9997                    NaN  2026-02-11T08:35:04
# 9998                    NaN  2026-02-11T08:35:04
# 9999                    NaN  2026-02-11T08:35:04
#
# [10000 rows x 15 columns]

# %%
import pandas as pd
import requests
from io import BytesIO

url = "https://www2.census.gov/programs-surveys/popest/geographies/2021/all-geocodes-v2021.xlsx"

df = pd.read_excel(url,engine="openpyxl",skiprows=4)

# %%
df
# Out:
#           Unnamed: 0         Unnamed: 1          Unnamed: 2  \
# 0      Summary Level  State Code (FIPS)  County Code (FIPS)
# 1                010                 00                 000
# 2                040                 01                 000
# 3                050                 01                 001
# 4                050                 01                 003
# ...              ...                ...                 ...
# 43829            050                 72                 145
# 43830            050                 72                 147
# 43831            050                 72                 149
# 43832            050                 72                 151
# 43833            050                 72                 153
#
#                            Unnamed: 3         Unnamed: 4  \
# 0      County Subdivision Code (FIPS)  Place Code (FIPS)
# 1                               00000              00000
# 2                               00000              00000
# 3                               00000              00000
# 4                               00000              00000
# ...                               ...                ...
# 43829                           00000              00000
# 43830                           00000              00000
# 43831                           00000              00000
# 43832                           00000              00000
# 43833                           00000              00000
#
#                            Unnamed: 5  \
# 0      Consolidtated City Code (FIPS)
# 1                               00000
# 2                               00000
# 3                               00000
# 4                               00000
# ...                               ...
# 43829                           00000
# 43830                           00000
# 43831                           00000
# 43832                           00000
# 43833                           00000
#
#                                               Unnamed: 6
# 0      Area Name (including legal/statistical area de...
# 1                                          United States
# 2                                                Alabama
# 3                                         Autauga County
# 4                                         Baldwin County
# ...                                                  ...
# 43829                                Vega Baja Municipio
# 43830                                  Vieques Municipio
# 43831                                 Villalba Municipio
# 43832                                  Yabucoa Municipio
# 43833                                    Yauco Municipio
#
# [43834 rows x 7 columns]
